# %%
import pandas as pd

# %%
wellcome = pd.read_excel(r'F:\Downloads\WELLCOME_APCspend2013_forThinkful.xlsx')
wellcome.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
wellcome['Journal title'] = wellcome['Journal title'].replace(['PLOSONE', 'PLOS ONE', 'PLOS 1', 'PLOS'], 'PLOS ONE')

wellcome['Journal title'] = wellcome['Journal title'].replace(['ACTA D', 'ACTA CRYSTALLOGRAPHICA SECTION D', 
'ACTA CRYSTALLOGRAPHICA D', 'ACTA CRYSTALLOGRAPHICA, SECTION D', 'ACTA CRYSTALLOGRAPHICA SECTION D, BIOLOGICAL CRYSTALLOGRAPHY'], 
'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY')

wellcome['Journal title'] = wellcome['Journal title'].replace(['AMERICAN JNL EPIDEMIOLOGY'], 'AMERICAN JOURNAL OF EPIDEMIOLOGY')

wellcome['Journal title'] = wellcome['Journal title'].replace(['ANTIMICROBIAL AGENTS AND CHEMOTHERAPY', 
'ANTIMICROBIAL AGENTS AND CHEMOTHERAPY'], 'ANTIMICROBIAL AGENTS & CHEMOTHERAPY')

wellcome['Journal title'] = wellcome['Journal title'].replace(['ANGEWANDTE CHEMIE', 'ANGEWANDTE CHEMIE INTERNATIONAL EDITION', 
'ANGEWANDTE INT ED'], 'ANGEWANDTE CHEMIE')

wellcome['Journal title'] = wellcome['Journal title'].replace(['BEHAVIOUR RESEARCH AND THERAPY'], 'BEHAVIOUR RESEARCH & THERAPY')

wellcome['Journal title'] = wellcome['Journal title'].replace(['BIOCHEM JOURNAL', 'BIOCHEMICAL JOURNALS'], 'BIOCHEMICAL JOURNAL')

wellcome['Journal title'] = wellcome['Journal title'].replace(['BIOCHEM SOC TRANS'], 'BIOCHEMICAL SOCIETY TRANSACTIONS')

wellcome['Journal title'] = wellcome['Journal title'].replace(['BRITISH JOURNAL OF OPHTHALMOLOGY'], 'BRITISH JOURNAL OF OPHTHALMOLOGY')

wellcome['Journal title'] = wellcome['Journal title'].replace(['CELL DEATH DIFFERENTIATION'], 'CELL DEATH & DIFFERENTIATION')

wellcome['Journal title'] = wellcome['Journal title'].replace(['CHILD: CARE, HEALTH DEVELOPMENT'], 'CHILD: CARE, HEALTH & DEVELOPMENT')

wellcome['Journal title'] = wellcome['Journal title'].replace(['CURR BIOL'], 'CURRENT BIOLOGY')

print(wellcome)
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
wellcome['Journal title'] = wellcome['Journal title'].apply(lambda x: str(x).strip().upper())

# %%
wellcome[ 'Journal title' ] = wellcome[ 'Journal title' ].fillna('')

wellcome[ 'journal_cleaned' ] = wellcome[ 'Journal title' ].str.replace('\d+', '')

wellcome[ 'journal_cleaned' ] = wellcome[ 'journal_cleaned' ].str.replace('[^\w\s]','' )

wellcome[ 'journal_cleaned' ] = wellcome[ 'journal_cleaned' ].str.strip()

wellcome[ 'journal_cleaned' ] = wellcome[ 'journal_cleaned' ].apply(lambda x: ''.join([word for word in x.split()]))
                                                                
wellcome[ 'journal_cleaned' ] = wellcome[ 'journal_cleaned' ].str.upper()

print('The Top 5 Journals and total Articles for each:')
print('(with a tie for 5th)')
wellcome['journal_cleaned'].value_counts().head(6)
# Out:
# The Top 5 Journals and total Articles for each:
# (with a tie for 5th)
# PLOSONE                         202
# JOURNALOFBIOLOGICALCHEMISTRY     53
# NEUROIMAGE                       29
# NUCLEICACIDSRESEARCH             26
# PLOSPATHOGENS                    24
# PLOSGENETICS                     24
# Name: journal_cleaned, dtype: int64

# %%
wellcome.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          PSYCHOLOGICAL MEDICINE
# 1               BIOMACROMOLECULES
# 2                      J MED CHEM
# 3                      J MED CHEM
# ...

# %%
sorted_data_by_group = wellcome.groupby('Journal title').aggregate('count').sort_values('Article title', ascending = False)

# %%
sorted_data_by_group
# Out:
#                                                     PMID/PMCID  Publisher  \
# Journal title
# PLOS ONE                                                   190        192
# JOURNAL OF BIOLOGICAL CHEMISTRY                             52         53
# NEUROIMAGE                                                  28         29
# NUCLEIC ACIDS RESEARCH                                      25         26
# PLOS GENETICS                                               23         24
# PLOS PATHOGENS                                              24         24
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES             22         22
# PLOS NEGLECTED TROPICAL DISEASES                            20         20
# NATURE COMMUNICATIONS                                       19         19
# HUMAN MOLECULAR GENETICS                                    17         19
# MOVEMENT DISORDERS                                          13         15
# ...

# %%
top_five_rows = sorted_data_by_group.iloc[:6, :]

# %%
top_five_rows
# Out:
#                                  PMID/PMCID  Publisher  Article title  \
# Journal title
# PLOS ONE                                190        192            192
# JOURNAL OF BIOLOGICAL CHEMISTRY          52         53             53
# NEUROIMAGE                               28         29             29
# NUCLEIC ACIDS RESEARCH                   25         26             26
# PLOS GENETICS                            23         24             24
# PLOS PATHOGENS                           24         24             24
#
#                                  COST (£) charged to Wellcome (inc VAT when charged)  \
# Journal title
# PLOS ONE                                                                       192
# JOURNAL OF BIOLOGICAL CHEMISTRY                                                 53
# NEUROIMAGE                                                                      29
# NUCLEIC ACIDS RESEARCH                                                          26
# ...

# %%
print('The Top 5 Journals and total Articles for each:')
print('(with a tie for 5th)')
top_five_rows['Article title'].value_counts().head(6)
# Out:
# The Top 5 Journals and total Articles for each:
# (with a tie for 5th)
# 24     2
# 53     1
# 29     1
# 26     1
# 192    1
# Name: Article title, dtype: int64

# %%
wellcome['journal_cleaned'] = wellcome['journal_cleaned'].apply(lambda x: '{}')

# %%
wellcome['COST (£) charged to Wellcome (inc VAT when charged)'] = wellcome['COST (£) charged to Wellcome (inc VAT when charged)'].str.lstrip('{£}').str.rstrip('{$}').astype(float)

for w in wellcome['COST (£) charged to Wellcome (inc VAT when charged)']:

    print(w)
# Out:
# 0.0
# 2381.04
# 642.56
# 669.64
# 685.88
# 2392.2
# 2367.95
# 649.33
# 1294.59
# 1294.78
# 1329.69
# 1287.2
# 1324.66
# 665.64
# 1006.72
# 238.08
# 265.67
# 2035.0
# 3108.08
# 1267.76
# 2286.73
# 947.07
# 1186.8
# 642.89
# 1533.29
# 2082.74
# 2314.1
# 759.67
# 1565.26
# 572.74
# 750.66
# 321.12
# 1321.88
# 1626.14
# 693.39
# 2383.94
# 1276.08
# 1291.02
# 1319.17
# 1514.35
# 1551.61
# 1314.58
# 1276.6
# 2351.73
# 2350.02
# 3021.72
# 3209.63
# 3211.77
# 2534.53
# 3188.3
# 2534.53
# 3037.86
# 3144.24
# 2659.32
# 3092.18
# 2973.32
# 2534.53
# 2973.32
# 2561.4
# 1422.25
# 1100.0
# 2259.64
# 1487.46
# 1531.08
# 1019.71
# 1119.61
# 1131.01
# 1137.51
# 1152.72
# 1160.09
# 1166.85
# 1261.44
# 1276.08
# 1540.0
# 1586.36
# 1664.94
# 1743.84
# 2501.07
# 955.0
# 969.68
# 1166.6
# 995.31
# 1287.19
# 1287.2
# 1521.66
# 3750.05
# 743.85
# 1653.18
# 2316.16
# 1910.82
# 2034.0
# 2249.43
# 1343.82
# 1312.59
# 1549.44
# 1585.64
# 1586.75
# 2363.45
# 1503.47
# 1871.85
# 45.94
# 1260.26
# 1260.26
# ...

# %%
wellcome['COST (£) charged to Wellcome (inc VAT when charged)'].mean()
# Out:
# 24067.33997179131

# %%
wellcome['COST (£) charged to Wellcome (inc VAT when charged)'].median()
# Out:
# 1884.01

# %%
wellcome['COST (£) charged to Wellcome (inc VAT when charged)'].std()
# Out:
# 146860.6655590476

# %%
sorted_data_by_group.mean()
# Out:
# PMID/PMCID                                             2.156600
# Publisher                                              2.379195
# Article title                                          2.379195
# COST (£) charged to Wellcome (inc VAT when charged)    2.379195
# journal_cleaned                                        2.379195
# dtype: float64

# %%
sorted_data_by_group.median()
# Out:
# PMID/PMCID                                             1.0
# Publisher                                              1.0
# Article title                                          1.0
# COST (£) charged to Wellcome (inc VAT when charged)    1.0
# journal_cleaned                                        1.0
# dtype: float64

# %%
sorted_data_by_group.std()
# Out:
# PMID/PMCID                                             7.015427
# Publisher                                              7.122701
# Article title                                          7.122701
# COST (£) charged to Wellcome (inc VAT when charged)    7.122701
# journal_cleaned                                        7.122701
# dtype: float64

# %%
top_five_rows.mean()
# Out:
# PMID/PMCID                                             57.0
# Publisher                                              58.0
# Article title                                          58.0
# COST (£) charged to Wellcome (inc VAT when charged)    58.0
# journal_cleaned                                        58.0
# dtype: float64

# %%
top_five_rows.median()
# Out:
# PMID/PMCID                                             26.5
# Publisher                                              27.5
# Article title                                          27.5
# COST (£) charged to Wellcome (inc VAT when charged)    27.5
# journal_cleaned                                        27.5
# dtype: float64

# %%
top_five_rows.std()
# Out:
# PMID/PMCID                                             66.066633
# Publisher                                              66.570264
# Article title                                          66.570264
# COST (£) charged to Wellcome (inc VAT when charged)    66.570264
# journal_cleaned                                        66.570264
# dtype: float64
